# %%
import numpy as np
import matplotlib.pyplot as plt

from gplearn.genetic import SymbolicRegressor
from gplearn.functions import make_function

from primel.samplers import (
    ImportanceSampler,
    RandomSampler,
    StratifiedSampler,
    LHSampler,
)
from primel.distributions import (
    Empirical,
    GaussianKDE,
    MultivariateUniform,
    MixtureModel,
    gaussian_kde,
)
from primel.early_stopping import EarlyStopping
from primel.adapters.gplearn import GPLearnAdapter
from primel.fitness import induced_kl_divergence

# %load_ext autoreload
# %autoreload 2

# %%
random_state = 42
n_train = 100

def generate_circle_data(n_points, noise):
    """Generate noisy circle data."""
    theta = np.linspace(0, 2 * np.pi, n_points)
    X = np.column_stack([np.cos(theta), np.sin(theta)])
    X += np.random.normal(0, noise, X.shape)
    return X

train_data = generate_circle_data(n_train, 0.00)

# %%
fig, ax = plt.subplots()
ax.scatter(train_data[:, 0], train_data[:, 1], s=10, color="blue")
ax.set_title("Training Data: Noisy Circle")
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_aspect('equal')
ax.grid(True)

plt.show()

# %%
# bandwidths = np.logspace(4, -8, 13)
# for bandwidth in bandwidths:
#     empirical_dist = Empirical(data=train_data)
#     gaussian_kde_dist = GaussianKDE(X=train_data, bandwidth=bandwidth)
#     uniform_dist = MultivariateUniform(X=train_data, margins=0.1, non_negative=False)

#     sampler_entries = [
#         ("train", RandomSampler(empirical_dist), n_train, 1),
#         ("kde", RandomSampler(gaussian_kde_dist), n_train // 2, 1),
#         ("uniform", LHSampler(uniform_dist), n_train * 2, 2),
#     ]

#     sampler = ImportanceSampler(sampler_entries=sampler_entries, random_state=random_state)
#     samples = sampler.samples

#     def f(x):
#         return x[:, 0]**2 + x[:, 1]**2 - 1

#     trivial_y = np.zeros(sampler.samples.shape[0])
#     true_y = f(sampler.samples)

#     trivial_fitness = induced_kl_divergence(
#         trivial_y,
#         sampler,
#         reference_dist=gaussian_kde_dist,
#         mean_center_on="train",
#     )
#     true_fitness = induced_kl_divergence(
#         true_y,
#         sampler,
#         reference_dist=gaussian_kde_dist,
#         mean_center_on="train",
#     )

#     # print(trivial_fitness, true_fitness, trivial_fitness < true_fitness)
#     print(f"{bandwidth} \t {trivial_fitness} \t {true_fitness} \t {trivial_fitness < true_fitness}")

# %%
empirical_dist = Empirical(data=train_data)
# bandwidth
gaussian_kde_dist = GaussianKDE(X=train_data, bandwidth=1e-1)
uniform_dist = MultivariateUniform(X=train_data, margins=0.1, non_negative=False)

# Override gplearns save equations
# 30 trials
# sweep parameter from here
sampler_entries = [
    ("train", RandomSampler(empirical_dist), n_train, 1),
    ("kde", RandomSampler(gaussian_kde_dist), n_train * 2, 1),
    ("uniform", LHSampler(uniform_dist), n_train * 2, 2),
]

sampler = ImportanceSampler(sampler_entries=sampler_entries, random_state=random_state)


samples = sampler.samples

# %%
from_train = sampler.get_samples("train")
from_kde = sampler.get_samples("kde")
from_uniform = sampler.get_samples("uniform")

plt.figure(figsize=(10, 8))
fig, ax = plt.subplots()
ax.scatter(from_train[:, 0], from_train[:, 1], s=10, color="blue", label="Train")
ax.scatter(from_kde[:, 0], from_kde[:, 1], s=10, color="orange", label="KDE")
ax.scatter(from_uniform[:, 0], from_uniform[:, 1], s=10, color="green", label="Uniform")
ax.set_title("Sampled Data from Importance Sampler by Distribution")
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_aspect('equal')
ax.grid(True)
ax.legend()

plt.show()

# %%
pdf_values = gaussian_kde_dist.pdf(sampler.samples)

plt.figure(figsize=(10, 8))
scatter = plt.scatter(
    sampler.samples[:, 0],
    sampler.samples[:, 1],
    c=pdf_values,
    cmap='viridis',
    alpha=0.7
)

cbar = plt.colorbar(scatter)
cbar.set_label("Probability Density (from Reference KDE)")

plt.title("Importance Sampler Points Colored by Reference Distribution Density")
plt.xlabel("X0")
plt.ylabel("X1")
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
# trivial_y = np.zeros(sampler.samples.shape[0])

# %%
# def f(x):
#     return x[:, 0]**2 + x[:, 1]**2 - 1

# true_y = f(sampler.samples)

# trivial_fitness = induced_kl_divergence(
#     trivial_y,
#     sampler,
#     reference_dist=gaussian_kde_dist,
#     mean_center_on="train",
# )
# true_fitness = induced_kl_divergence(
#     true_y,
#     sampler,
#     reference_dist=gaussian_kde_dist,
#     mean_center_on="train",
# )

# trivial_fitness, true_fitness

# %%
def _protected_division(x1, x2):
    """Closure of division (x1/x2) for zero denominator."""
    with np.errstate(divide='ignore', invalid='ignore'):
        return np.where(np.abs(x2) > 1e-10, np.divide(x1, x2), 1.)

div2 = make_function(function=_protected_division,
                        name='div',
                        arity=2)

# %%
early_stopping = EarlyStopping(
    sampler=sampler,
    train_X="train",
    total_variance_threshold=1e-4,
    training_variance_threshold=1e-6,
)
adapter = GPLearnAdapter(
    sampler=sampler,
    reference_distribution=gaussian_kde_dist,
    early_stopping=early_stopping,
    mean_center_on="train",
    lambda_=1.0,
    exponent=1.0,
)

est_gp = SymbolicRegressor(
    function_set=['add', 'sub', 'mul', div2],
    metric=adapter.get_fitness(),
    population_size=1000,
    generations=20,
    stopping_criteria=0.0,
    p_crossover=0.7,
    p_subtree_mutation=0.1,
    p_hoist_mutation=0.05,
    p_point_mutation=0.1,
    max_samples=0.9,
    verbose=1,
    # parsimony_coefficient=0.01,
    parsimony_coefficient="auto",
    random_state=random_state,
)

est_gp.fit(sampler.samples, np.zeros(sampler.samples.shape[0]))
print(est_gp._program)
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 33
#       7 adapter = GPLearnAdapter(
#       8     sampler=sampler,
#       9     reference_distribution=gaussian_kde_dist,
#    (...)     13     exponent=1.0,
#      14 )
#      16 est_gp = SymbolicRegressor(
#      17     function_set=['add', 'sub', 'mul', div2],
#      18     metric=adapter.get_fitness(),
#    (...)     30     random_state=random_state,
#      31 )
# ---> 33 est_gp.fit(sampler.samples, np.zeros(sampler.samples.shape[0]))
#      34 print(est_gp._program)
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/gplearn/genetic.py:476, in BaseSymbolic.fit(self, X, y, sample_weight)
#     472 n_jobs, n_programs, starts = _partition_estimators(
#     473     self.population_size, self.n_jobs)
#     474 seeds = random_state.randint(MAX_INT, size=self.population_size)
# --> 476 population = Parallel(n_jobs=n_jobs,
#     477                       verbose=int(self.verbose > 1))(
#     478     delayed(_parallel_evolve)(n_programs[i],
#     479                               parents,
#     480                               X,
#     481                               y,
#     482                               sample_weight,
#     483                               seeds[starts[i]:starts[i + 1]],
#     484                               params)
#     485     for i in range(n_jobs))
#     487 # Reduce, maintaining order across different n_jobs
#     488 population = list(itertools.chain.from_iterable(population))
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/gplearn/genetic.py:147, in _parallel_evolve(n_programs, parents, X, y, sample_weight, seeds, params)
#     144 curr_sample_weight[not_indices] = 0
#     145 oob_sample_weight[indices] = 0
# --> 147 program.raw_fitness_ = program.raw_fitness(X, y, curr_sample_weight)
#     148 if max_samples < n_samples:
#     149     # Calculate OOB fitness
#     150     program.oob_fitness_ = program.raw_fitness(X, y, oob_sample_weight)
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/gplearn/_program.py:465, in _Program.raw_fitness(self, X, y, sample_weight)
#     463 if self.transformer:
#     464     y_pred = self.transformer(y_pred)
# --> 465 raw_fitness = self.metric(y, y_pred, sample_weight)
#     467 return raw_fitness
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/gplearn/fitness.py:49, in _Fitness.__call__(self, *args)
#      48 def __call__(self, *args):
# ---> 49     return self.function(*args)
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/joblib/externals/loky/cloudpickle_wrapper.py:32, in CallableObjectWrapper.__call__(self, *args, **kwargs)
#      31 def __call__(self, *args, **kwargs):
# ---> 32     return self._obj(*args, **kwargs)
#
# File ~/Research/code/sr_rewrite/src/primel/adapters/gplearn/adapter.py:45, in GPLearnAdapter.get_fitness.<locals>._induced_kl_divergence(_y, y_pred, _w)
#      37 if len(y_pred) != len(self.sampler.samples):
#      38     raise ValueError(
#      39         (
#      40             f"Number of predictions ({len(y_pred)}) does not "
#      41             f"match number of samples ({len(self.sampler.samples)})."
#      42         )
#      43     )
# ---> 45 score = induced_kl_divergence(
#      46     f_vals=y_pred,
#      47     sampler=self.sampler,
#      48     reference_dist=self.reference_distribution,
#      49     lambda_=self.lambda_,
#      50     exponent=self.exponent,
#      51     mean_center_on=self.mean_center_on,
#      52 )
#      54 return score
#
# File ~/Research/code/sr_rewrite/src/primel/fitness.py:40, in induced_kl_divergence(f_vals, sampler, reference_dist, lambda_, exponent, mean_center_on)
#      37         f_vals = f_vals - centering_mean
#      39 candidate_dist_unnorm = np.exp(-lambda_ * np.abs(f_vals) ** exponent)
# ---> 40 reference_dist_unnorm = reference_dist.pdf(sampler.samples)
#      42 candidate_dist_norm = candidate_dist_unnorm / (
#      43     np.sum(sampler.weights * candidate_dist_unnorm) + epsilon
#      44 )
#      45 reference_dist_norm = reference_dist_unnorm / (
#      46     np.sum(sampler.weights * reference_dist_unnorm) + epsilon
#      47 )
#
# File ~/Research/code/sr_rewrite/src/primel/distributions.py:138, in GaussianKDE.pdf(self, query_points)
#     136 def pdf(self: Self, query_points: np.ndarray) -> np.ndarray:
#     137     query_points = _validate_query_points(query_points, self.shape[1])
# --> 138     return self._gaussian_kde.evaluate(query_points.T)
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/scipy/stats/_kde.py:280, in gaussian_kde.evaluate(self, points)
#     277         raise ValueError(msg)
#     279 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 280 result = gaussian_kernel_estimate[spec](
#     281     self.dataset.T, self.weights[:, None],
#     282     points.T, self.cho_cov, output_dtype)
#     284 return result[:, 0]
#
# File scipy/stats/_stats.pyx:781, in scipy.stats._stats.gaussian_kernel_estimate()
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/scipy/_lib/_util.py:1233, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1231 # Early exit if call is not batched
#    1232 if not any(batch_shapes):
# -> 1233     return f(*arrays, *other_args, **kwargs)
#    1235 # Determine broadcasted batch shape
#    1236 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/scipy/linalg/_basic.py:507, in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     503     return np.empty_like(b1, dtype=dt_nonempty)
#     505 overwrite_b = overwrite_b or _datacopied(b1, b)
# --> 507 x, _ = _solve_triangular(a1, b1, trans, lower, unit_diagonal, overwrite_b)
#     508 return x
#
# File ~/Research/code/sr_rewrite/.venv/lib/python3.13/site-packages/scipy/linalg/_basic.py:518, in _solve_triangular(a1, b1, trans, lower, unit_diagonal, overwrite_b)
#     516 trtrs, = get_lapack_funcs(('trtrs',), (a1, b1))
#     517 if a1.flags.f_contiguous or trans == 2:
# --> 518     x, info = trtrs(a1, b1, overwrite_b=overwrite_b, lower=lower,
#     519                     trans=trans, unitdiag=unit_diagonal)
#     520 else:
#     521     # transposed system is solved since trtrs expects Fortran ordering
#     522     x, info = trtrs(a1.T, b1, overwrite_b=overwrite_b, lower=not lower,
#     523                     trans=not trans, unitdiag=unit_diagonal)
#
# KeyboardInterrupt:

# %%
from gplearn.functions import _Function

rng = np.random.RandomState(random_state)
# program = est_gp._program.build_program(rng)
program = est_gp._program.program
# print(program)

for p in program:
    # print(type(p))
    if isinstance(p, _Function):
        print(p.name)
    else:
        print(p)

# %%
from primel.adapters.gplearn._tree import build_tree
root = build_tree(program)
print(root)

# %%
pred_y = est_gp.predict(sampler.samples)

# %%
induced_kl_divergence(
    pred_y,
    sampler,
    reference_dist=gaussian_kde_dist,
    mean_center_on="train",
)

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(
    sampler.samples[:, 0],
    sampler.samples[:, 1],
    c=pred_y,
    cmap='viridis',
    alpha=0.7
)

cbar = plt.colorbar(scatter)
cbar.set_label("Probability Density (from Reference KDE)")

plt.title("Importance Sampler Points Colored by Reference Distribution Density")
plt.xlabel("X0")
plt.ylabel("X1")
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
def f(x):
    return x[:, 0]**2 + x[:, 1]**2 - 1
    
true_y = f(sampler.samples)
induced_kl_divergence(
    true_y,
    sampler,
    reference_dist=gaussian_kde_dist,
    mean_center_on="train",
)

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(
    sampler.samples[:, 0],
    sampler.samples[:, 1],
    c=true_y,
    cmap='viridis',
    alpha=0.7
)

cbar = plt.colorbar(scatter)
cbar.set_label("Probability Density (from Reference KDE)")

plt.title("Importance Sampler Points Colored by Reference Distribution Density")
plt.xlabel("X0")
plt.ylabel("X1")
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()
